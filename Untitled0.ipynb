# %% [markdown]
# <a href="https://colab.research.google.com/github/gwaisvol/python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from google.colab import drive
drive.mount('/drive/', force_remount=True)
ruta = '/drive/MyDrive/PrimeraEntrega'
# Out:
# Mounted at /drive/

# %%
def registro(BD):
 
    usuario=input("Ingrese el nombre de usuario:")
    if usuario in BD.keys():
      print("Ese usuario ya existe")
    else:
      password=input("Ingrese la contraseña:")
      BD[usuario] = password

# %%
def leerData(BD):
  print("La info almacenada en la base de datos es:")
  for usuario, password in BD.items():
    print("usuario:", usuario, "password:", BD[usuario])

# %%
def guardarArchivo(BD):
  with open(ruta + "/archivo.txt", "w") as file:
    json.dump(BD, file, indent=4)

# %%
def login(BD):
    usuario=input("Ingrese su usuario:")
    if usuario in BD.keys():
      password=input("Ingrese su contraseña:")
      if(BD[usuario] == password):
        print("Has ingresado  correctamente")
      else:
        print("Contraseña incorrecta")
    else:
      print("Usuario inexistente")

# %%
BD = {}
registro(BD)
registro(BD)
leerData(BD)
login(BD)
guardarArchivo(BD)
# Out:
# Ingrese el nombre de usuario:german
# Ingrese la contraseña:pepe1234
# Ingrese el nombre de usuario:raul
# Ingrese la contraseña:8989
# La info almacenada en la base de datos es:
# usuario: german password: pepe1234
# usuario: raul password: 8989
# Ingrese su usuario:german
# Ingrese su contraseña:pepe1234
# Has ingresado  correctamente
